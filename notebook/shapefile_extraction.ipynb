# %%
import osmnx as ox
import json
import matplotlib.pyplot as plt

# Get the boundary polygon for New York City
gdf = ox.geocode_to_gdf('New York City, USA')

# Plot the GeoDataFrame
gdf.plot()
plt.show()

gdf.to_file("new_york_city.geojson", driver='GeoJSON')
